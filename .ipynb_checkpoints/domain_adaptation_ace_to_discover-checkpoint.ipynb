# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor
from lightgbm import LGBMRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.cross_decomposition import PLSRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.base import clone

import warnings
warnings.filterwarnings('ignore')

# %%
data_ace_24 = pd.read_csv("../data/Ace_погружение_24часа.csv", sep=';', decimal=',', parse_dates=['datetime'], index_col='datetime')
data_discover_24 = pd.read_csv("../data/Discover_погружение_24часа.csv", sep=';', decimal=',', parse_dates=['datetime'], index_col='datetime')
data_ace_af = pd.read_csv("../data/Ace_погружение_AF.csv", sep=';', decimal=',', parse_dates=['datetime'], index_col='datetime')
data_discover_af = pd.read_csv("../data/Discover_погружение_AF.csv", sep=';', decimal=',', parse_dates=['datetime'], index_col='datetime')

# %%
def build_models_adaptation():
    models = {
        "linreg": LinearRegression(),
        "boost": LGBMRegressor(
            n_estimators=1000,
            reg_alpha=0.7,
            reg_lambda=0.7,
            max_depth=3,
            subsample=0.8,
            colsample_bytree=0.8,
            random_state=42,
            verbose=-1),
        "pls": PLSRegression(n_components=100,
            scale=True,
            max_iter=2000)
    }
    return models

def adapt_ace_to_discover(ace_df, disc_df, future_lags, split_date="2022-01-01", adapt_model_name="linreg"):
    """
    Адаптация ace -> discover

    1. K обучается только на пересечении тренировочных данных ace и discover
    2. Ace до появления discover адаптируется в домен discover
    3. Возвращаются адаптированный ace_old_train и discr_train, disc_test
    """

    ace = ace_df.sort_index()
    disc = disc_df.sort_index()
    split_date = pd.Timestamp(split_date)

    ace_train = ace.loc[:split_date]
    disc_train = disc.loc[:split_date]
    disc_test = disc.loc[split_date:]

    overlap_idx = ace_train.index.intersection(disc_train.index)

    ace_overlap = ace_train.loc[overlap_idx]
    disc_overlap = disc_train.loc[overlap_idx]

    feature_cols = [c for c in ace.columns if c not in future_lags]

    sc_ace = StandardScaler().fit(ace_overlap[feature_cols])
    sc_disc = StandardScaler().fit(disc_overlap[feature_cols])

    X_ace = sc_ace.transform(ace_overlap[feature_cols])
    X_disc = sc_disc.transform(disc_overlap[feature_cols])

    # Модель адаптации K: ace -> discover
    models = build_models_adaptation()
    
    if adapt_model_name not in models:
        raise ValueError(f"Неизвестная модель: {adapt_model_name}. Доступны: {list(models.keys())}")
    
    K = models[adapt_model_name]

    # Используем, так как таргет многомерный
    if adapt_model_name == "boost":
        from sklearn.multioutput import MultiOutputRegressor
        K = MultiOutputRegressor(K)
        
    K.fit(X_ace, X_disc)

    # ace до появления discover
    ace_old = ace.loc[:disc.index.min()]
    ace_old = ace_old[feature_cols]

    X_ace_old = sc_ace.transform(ace_old)
    X_ace_old_adapted = K.predict(X_ace_old)
    X_ace_old_adapted = sc_disc.inverse_transform(X_ace_old_adapted)

    ace_old_adapted = pd.DataFrame(X_ace_old_adapted, index=ace_old.index, columns=feature_cols)

    for col in future_lags:
        ace_old_adapted[col] = ace_df.loc[ace_old.index, col]

    return ace_old_adapted, disc_train, disc_test, K, sc_ace, sc_disc

# %%
def cross_adapt_domain(ace_df, disc_df, future_lags,
                       split_date="2022-01-01",
                       wind_model_type="LGBM"):
    """
    - ace_old_adapted : адаптированный в домен DISCOVR старый ACE (до появления DISCOVR)
    - disc_train      : обучающая часть DISCOVR
    - disc_test       : тестовая часть DISCOVR (как есть)
    - models_dict     : словарь обученных моделей адаптации (fields + wind)
    """
    ace = ace_df.sort_index()
    disc = disc_df.sort_index()
    split_date = pd.Timestamp(split_date)

    ace_train = ace.loc[:split_date]
    disc_train = disc.loc[:split_date]
    disc_test = disc.loc[split_date:]

    overlap_idx = ace_train.index.intersection(disc_train.index)
    ace_overlap = ace_train.loc[overlap_idx]
    disc_overlap = disc_train.loc[overlap_idx]

    field_features = ace.filter(regex=r'^(Dst|bx_gsm|by_gsm|bz_gsm|bt)(_lag\d+)?$').columns.tolist()
    wind_features = ace.filter(regex=r'^(proton_density|proton_speed|proton_temperature)(_lag\d+)?$').columns.tolist()

    field_features = [c for c in field_features if c in ace.columns and c in disc.columns]
    wind_features  = [c for c in wind_features  if c in ace.columns and c in disc.columns]

    field_model_tpl = Pipeline([
        ("scaler", StandardScaler()),
        ("lin", LinearRegression())
    ])

    field_models = {}

    # обучаем по пересечению времён (ace_overlap -> disc_overlap)
    for col in field_features:
        X_ace_col  = ace_overlap[[col]]
        y_disc_col = disc_overlap[col]

        m = clone(field_model_tpl)
        m.fit(X_ace_col, y_disc_col)
        field_models[col] = m

    if wind_model_type == "LGBM":
        base_wind_est = LGBMRegressor(
            n_estimators=1000,
            reg_alpha=0.7,
            reg_lambda=0.7,
            max_depth=3,
            subsample=0.8,
            colsample_bytree=0.8,
            random_state=42,
            verbose=-1
        )
    else:
        base_wind_est = MLPRegressor(
            hidden_layer_sizes=(8, 4),
            solver='adam',
            alpha=1e-3,
            batch_size=64,
            learning_rate_init=5e-4,
            early_stopping=True,
            validation_fraction=0.15,
            max_iter=1500,
            random_state=42,
            verbose=False
        )

    def make_wind_model():
        return Pipeline([
            ("scaler", StandardScaler()),
            ("model", clone(base_wind_est))
        ])

    wind_models = {}

    if wind_features:
        X_ace_wind  = ace_overlap[wind_features]
        X_disc_wind = disc_overlap[wind_features]

        for target_col in wind_features:
            m = make_wind_model()
            m.fit(X_ace_wind, X_disc_wind[target_col])
            wind_models[target_col] = m

    ace_old = ace.loc[:disc.index.min()]
    ace_old_adapted = ace_old.copy()

    for col, m in field_models.items():
        if col in ace_old.columns:
            ace_old_adapted[col] = m.predict(ace_old[[col]])

    if wind_features:
        X_ace_old_wind = ace_old[wind_features]
        for col, m in wind_models.items():
            ace_old_adapted[col] = m.predict(X_ace_old_wind)

    for col in future_lags:
        if col in ace_df.columns:
            ace_old_adapted[col] = ace_df.loc[ace_old.index, col]

    models_dict = {
        "fields": field_models,
        "wind": wind_models
    }

    return ace_old_adapted, disc_train, disc_test, models_dict

# %%
def build_models(random_state=42):
    models = {}
    models['Linear'] = Pipeline([
        ("scaler", StandardScaler()),
        ("lin", LinearRegression())
    ])
    
    models['Ridge'] = Pipeline([
        ("scaler", StandardScaler()),
        ("ridge", Ridge(
            alpha=1.0,
            solver='auto',
            random_state=random_state))
    ])

    models['Lasso'] = Pipeline([
        ("scaler", StandardScaler()),
        ("lasso", Lasso(
            alpha=0.0005,
            tol=0.01,
            max_iter=500, 
            random_state=random_state))
    ])
    
    models['LGBM'] = Pipeline([
        ("boost", LGBMRegressor(
            boosting_type='gbdt',
            num_leaves=93,
            max_depth=5,
            learning_rate=0.014357868416776678,
            n_estimators=1160,
            # subsample_for_bin=200000,
            objective=None,
            class_weight=None,
            min_split_gain=0.0,
            min_child_weight=0.001,
            min_child_samples=25,
            subsample=0.5606239658637814,
            subsample_freq=0,
            colsample_bytree=0.9879825765791656,
            reg_alpha=0.022687699993507067,
            reg_lambda=0.005915305250069859,
            random_state=random_state,
            n_jobs=None,
            importance_type='split',
            metric='rmse',
            # early_stopping_rounds=50,
            verbose=-1))
    ])
    
    models['MLP'] = Pipeline([
        ("scaler", StandardScaler()),
        ("mlp", MLPRegressor(
            hidden_layer_sizes=(12,),
            solver='adam',
            alpha=1e-4,
            batch_size=32,
            learning_rate_init=1e-3,
            early_stopping=True,
            validation_fraction=0.1,
            max_iter=1500,
            random_state=random_state))
    ])
    return models

def evaluate_M_D(ace_old_adapted, disc_train, disc_test,
                      split_date, target, future_lags,
                      adaptation_method='linreg',
                      delays='24h',
                      random_seed=42,
                      verbose=True):
    """
    Обучение M_D:
    - train = адаптированный старый ace + discover_train
    - test = discover_test
    """

    models = build_models(random_state=random_seed)

    train_adapt = pd.concat([ace_old_adapted, disc_train], axis=0).sort_index()

    feature_cols = [c for c in train_adapt.columns if c not in future_lags]

    X_train = train_adapt[feature_cols].values
    y_train = train_adapt[target].values

    X_test = disc_test[feature_cols].values
    y_test = disc_test[target].values
    
    run_results = []

    # if verbose:
    #     print(f"\n=== M_D | target={target} | adapt={adaptation_method} | seed={random_seed} ===")

    for name, model in models.items():
        try:
            if name == 'LGBM':
                X_tr, X_val, y_tr, y_val = train_test_split(
                    X_train, y_train, test_size=0.1, random_state=random_seed)

                model.fit(
                    X_tr, y_tr,
                    boost__eval_set=[(X_val, y_val)],
                    boost__eval_metric='l2')
                
            else:
                model.fit(X_train, y_train)
            
            y_pred = model.predict(X_test)

            rmse = np.sqrt(mean_squared_error(y_test, y_pred))
            mae  = mean_absolute_error(y_test, y_pred)
            r2   = r2_score(y_test, y_pred)

            # if verbose:
            #     print(f"{name:8s} seed={random_seed}: rmse={rmse:.4f}, mae={mae:.4f}, r2={r2:.4f}")

            run_results.append({
                'target': target,
                'delays': delays,
                'adaptation_method': adaptation_method,
                'forecast_model': name,
                'seed': random_seed,
                'RMSE': rmse,
                'MAE': mae,
                'R2':  r2
            })
        except Exception as e:
            print(f"{name:8s} seed={random_seed} -> Ошибка обучения: {e}")

    return run_results

# %%
def evaluate_M_D_with_error(ace_old_adapted, disc_train, disc_test, split_date, target, future_lags,
                            adaptation_method='linreg', delays='24h',
                            n_seeds=5, base_seed=42,
                            results_list=None, verbose=True):
    if results_list is None:
        results_list = []

    single_run = evaluate_M_D(
        ace_old_adapted,
        disc_train,
        disc_test,
        split_date,
        target,
        future_lags,
        adaptation_method=adaptation_method,
        delays=delays,
        random_seed=base_seed,
        verbose=verbose
    )
    df_single = pd.DataFrame(single_run)

    seeds = [base_seed + i for i in range(n_seeds)]
    stochastic_models = ['LGBM', 'MLP']

    all_runs_stochastic = []
    for seed in seeds:
        run_results = evaluate_M_D(
            ace_old_adapted,
            disc_train,
            disc_test,
            split_date,
            target,
            future_lags,
            adaptation_method=adaptation_method,
            delays=delays,
            random_seed=seed,
            verbose=False
        )
        run_results = [r for r in run_results if r['forecast_model'] in stochastic_models]
        all_runs_stochastic.extend(run_results)

    df_stoch = pd.DataFrame(all_runs_stochastic)

    records = []

    linear_models = ['Linear', 'Ridge', 'Lasso']
    df_linear = df_single[df_single['forecast_model'].isin(linear_models)]

    for _, row in df_linear.iterrows():
        records.append({
            'target': row['target'],
            'delays': delays,
            'adaptation_method': adaptation_method,
            'forecast_model': row['forecast_model'],
            'RMSE': row['RMSE'],
            'RMSE_std': 0.0,
            'MAE': row['MAE'],
            'MAE_std': 0.0,
            'R2': row['R2'],
            'R2_std': 0.0,
            'n_seeds': 1,
            'base_seed': base_seed
        })

    if not df_stoch.empty:
        group_cols = ['target', 'adaptation_method', 'forecast_model', 'delays']
        agg = df_stoch.groupby(group_cols).agg({
            'RMSE': ['mean', 'std'],
            'MAE': ['mean', 'std'],
            'R2': ['mean', 'std']
        }).reset_index()

        agg.columns = ['target', 'adaptation_method', 'forecast_model', 'delays',
                       'RMSE_mean', 'RMSE_std',
                       'MAE_mean', 'MAE_std',
                       'R2_mean', 'R2_std']

        for _, row in agg.iterrows():
            records.append({
                'target': row['target'],
                'delays': row['delays'],
                'adaptation_method': row['adaptation_method'],
                'forecast_model': row['forecast_model'],
                'RMSE': row['RMSE_mean'],
                'RMSE_std': row['RMSE_std'],
                'MAE': row['MAE_mean'],
                'MAE_std': row['MAE_std'],
                'R2': row['R2_mean'],
                'R2_std': row['R2_std'],
                'n_seeds': n_seeds,
                'base_seed': base_seed
            })

    results_list.extend(records)

    if not df_stoch.empty:
        df_all = pd.concat([df_single, df_stoch], ignore_index=True)
    else:
        df_all = df_single.copy()

    agg_df = pd.DataFrame(records)

    if verbose:
        for _, row in agg_df.iterrows():
            print(f"{row['forecast_model']:8s}: "
                  f"RMSE = {row['RMSE']:.4f} ± {row['RMSE_std']:.4f}, "
                  f"MAE = {row['MAE']:.4f} ± {row['MAE_std']:.4f}, "
                  f"R2 = {row['R2']:.4f} ± {row['R2_std']:.4f}")

    return df_all, agg_df, results_list

# %%
# 0. Копирование загруженных данных в отдельные переменные
data_ace_24_copy = data_ace_24.copy()
data_discover_24_copy = data_discover_24.copy()
data_ace_af_copy = data_ace_af.copy()
data_discover_af_copy = data_discover_af.copy()

cutoff_date = pd.Timestamp('2023-12-31 23:59:59')

data_ace_24_copy = data_ace_24_copy[data_ace_24_copy.index <= cutoff_date]
data_discover_24_copy = data_discover_24_copy[data_discover_24_copy.index <= cutoff_date]

data_ace_af_copy = data_ace_af_copy[data_ace_af_copy.index <= cutoff_date]
data_discover_af_copy = data_discover_af_copy[data_discover_af_copy.index <= cutoff_date]

# 1. Задание переменных для адаптации
split_date = "2022-01-01"
future_lags = [f'Dst_plus{i}' for i in range(1, 25)] # все сдвиги во времени вперед (задаются при обработке данных)
# targets = ['Dst_plus1', 'Dst_plus2', 'Dst_plus3', 'Dst_plus6', 'Dst_plus12', 'Dst_plus24'] # таргеты, на которые делаем прогнозы
targets = ['Dst_plus1', 'Dst_plus3', 'Dst_plus6']

# %%
# 2.1. Доменная адаптация с помощью моделей линейной регрессии (linreg), градиентного бустинга (boost) и метода проекций на латентные структуры (pls)
ace_adapted_lin_24, disc_train_24, disc_test_24, K_lin_24, sd_lin_24, sa_lin_24 = adapt_ace_to_discover(
    data_ace_24_copy,
    data_discover_24_copy,
    future_lags,
    split_date,
    adapt_model_name="linreg"
)

ace_adapted_gbr_24, disc_train_24, disc_test_24, K_gbr_24, sd_gbr_24, sa_gbr_24 = adapt_ace_to_discover(
    data_ace_24_copy,
    data_discover_24_copy,
    future_lags,
    split_date,
    adapt_model_name="boost"
)

ace_adapted_pls_24, disc_train_24, disc_test_24, K_pls_24, sd_pls_24, sa_pls_24 = adapt_ace_to_discover(
    data_ace_24_copy,
    data_discover_24_copy,
    future_lags,
    split_date,
    adapt_model_name="pls"
)

# %%
ace_adapted_lin_af, disc_train_af, disc_test_af, K_lin_af, sd_lin_af, sa_lin_af = adapt_ace_to_discover(
    data_ace_af_copy,
    data_discover_af_copy,
    future_lags,
    split_date,
    adapt_model_name="linreg"
)

ace_adapted_gbr_af, disc_train_af, disc_test_af, K_gbr_af, sd_gbr_af, sa_gbr_af = adapt_ace_to_discover(
    data_ace_af_copy,
    data_discover_af_copy,
    future_lags,
    split_date,
    adapt_model_name="boost"
)

ace_adapted_pls_af, disc_train_af, disc_test_af, K_pls_af, sd_pls_af, sa_pls_af = adapt_ace_to_discover(
    data_ace_af_copy,
    data_discover_af_copy,
    future_lags,
    split_date,
    adapt_model_name="pls"
)

# %%
results_list = []

# %%
print("\n==== Depth - 24h ====")

print("\n==== Adaptation - linreg ====")
for target in targets:
    print(f"\n==== Forecast of {target.upper()} ====")
    df_all, df_sum, results_list = evaluate_M_D_with_error(
        ace_old_adapted=ace_adapted_lin_24,
        disc_train=disc_train_24,
        disc_test=disc_test_24,
        split_date=split_date,
        target=target,
        future_lags=future_lags,
        adaptation_method='ace-disc-linreg',
        delays='24h',
        n_seeds=3,
        base_seed=42,
        results_list=results_list
    )

print("\n==== Adaptation - lgbm ====")
for target in targets:
    print(f"\n==== Forecast of {target.upper()} ====")
    df_all, df_sum, results_list = evaluate_M_D_with_error(
        ace_old_adapted=ace_adapted_gbr_24,
        disc_train=disc_train_24,
        disc_test=disc_test_24,
        split_date=split_date,
        target=target,
        future_lags=future_lags,
        adaptation_method='ace-disc-lgbm',
        delays='24h',
        n_seeds=3,
        base_seed=42,
        results_list=results_list
    )

print("\n==== Adaptation - pls ====")
for target in targets:
    print(f"\n==== Forecast of {target.upper()} ====")
    df_all, df_sum, results_list = evaluate_M_D_with_error(
        ace_old_adapted=ace_adapted_pls_24,
        disc_train=disc_train_24,
        disc_test=disc_test_24,
        split_date=split_date,
        target=target,
        future_lags=future_lags,
        adaptation_method='ace-disc-pls',
        delays='24h',
        n_seeds=3,
        base_seed=42,
        results_list=results_list
    )
# Out:
# ==== Depth - 24h ====
#
# ==== Adaptation - linreg ====
#
# ==== Forecast of DST_PLUS1 ====
# Linear  : RMSE = 3.3117 ± 0.0000, MAE = 2.3775 ± 0.0000, R2 = 0.9679 ± 0.0000
# Ridge   : RMSE = 3.3116 ± 0.0000, MAE = 2.3774 ± 0.0000, R2 = 0.9679 ± 0.0000
# Lasso   : RMSE = 3.3122 ± 0.0000, MAE = 2.3761 ± 0.0000, R2 = 0.9679 ± 0.0000
# LGBM    : RMSE = 3.4495 ± 0.0585, MAE = 2.4062 ± 0.0062, R2 = 0.9652 ± 0.0012
# MLP     : RMSE = 3.3381 ± 0.0273, MAE = 2.4170 ± 0.0166, R2 = 0.9674 ± 0.0005
#
# ==== Forecast of DST_PLUS3 ====
# Linear  : RMSE = 6.7052 ± 0.0000, MAE = 4.8228 ± 0.0000, R2 = 0.8683 ± 0.0000
# Ridge   : RMSE = 6.7052 ± 0.0000, MAE = 4.8228 ± 0.0000, R2 = 0.8683 ± 0.0000
# Lasso   : RMSE = 6.7037 ± 0.0000, MAE = 4.8210 ± 0.0000, R2 = 0.8684 ± 0.0000
# LGBM    : RMSE = 6.5602 ± 0.0195, MAE = 4.7030 ± 0.0117, R2 = 0.8740 ± 0.0008
# MLP     : RMSE = 6.6148 ± 0.0410, MAE = 4.7463 ± 0.0332, R2 = 0.8718 ± 0.0016
#
# ==== Forecast of DST_PLUS6 ====
# ...

# %%
print(f"\n==== Depth - autocorrelation function ====")

print("\n==== Adaptation - linreg ====")
for target in targets:
    print(f"\n==== Forecast of {target.upper()} ====")
    df_all, df_sum, results_list = evaluate_M_D_with_error(
        ace_old_adapted=ace_adapted_lin_af,
        disc_train=disc_train_af,
        disc_test=disc_test_af,
        split_date=split_date,
        target=target,
        future_lags=future_lags,
        adaptation_method='ace-disc-linreg',
        delays='auto_func',
        n_seeds=5,
        base_seed=42,
        results_list=results_list
    )

print("\n==== Adaptation - lgbm ====")
for target in targets:
    print(f"\n==== Forecast of {target.upper()} ====")
    df_all, df_sum, results_list = evaluate_M_D_with_error(
        ace_old_adapted=ace_adapted_gbr_af,
        disc_train=disc_train_af,
        disc_test=disc_test_af,
        split_date=split_date,
        target=target,
        future_lags=future_lags,
        adaptation_method='ace-disc-lgbm',
        delays='auto_func',
        n_seeds=5,
        base_seed=42,
        results_list=results_list
    )

print("\n==== Adaptation - pls ====")
for target in targets:
    print(f"\n==== Forecast of {target.upper()} ====")
    df_all, df_sum, results_list = evaluate_M_D_with_error(
        ace_old_adapted=ace_adapted_pls_af,
        disc_train=disc_train_af,
        disc_test=disc_test_af,
        split_date=split_date,
        target=target,
        future_lags=future_lags,
        adaptation_method='ace-disc-pls',
        delays='auto_func',
        n_seeds=5,
        base_seed=42,
        results_list=results_list
    )
# Out:
# ==== Depth - autocorrelation function ====
#
# ==== Adaptation - linreg ====
#
# ==== Forecast of DST_PLUS1 ====
# Linear  : RMSE = 3.3170 ± 0.0000, MAE = 2.3801 ± 0.0000, R2 = 0.9676 ± 0.0000
# Ridge   : RMSE = 3.3170 ± 0.0000, MAE = 2.3801 ± 0.0000, R2 = 0.9676 ± 0.0000
# Lasso   : RMSE = 3.3177 ± 0.0000, MAE = 2.3796 ± 0.0000, R2 = 0.9676 ± 0.0000
# LGBM    : RMSE = 3.4411 ± 0.0425, MAE = 2.3979 ± 0.0102, R2 = 0.9652 ± 0.0009
# MLP     : RMSE = 3.3178 ± 0.0243, MAE = 2.3968 ± 0.0208, R2 = 0.9676 ± 0.0005
#
# ==== Forecast of DST_PLUS3 ====
# Linear  : RMSE = 6.7631 ± 0.0000, MAE = 4.8747 ± 0.0000, R2 = 0.8654 ± 0.0000
# Ridge   : RMSE = 6.7630 ± 0.0000, MAE = 4.8746 ± 0.0000, R2 = 0.8654 ± 0.0000
# Lasso   : RMSE = 6.7616 ± 0.0000, MAE = 4.8733 ± 0.0000, R2 = 0.8655 ± 0.0000
# LGBM    : RMSE = 6.5319 ± 0.0194, MAE = 4.7180 ± 0.0077, R2 = 0.8745 ± 0.0007
# MLP     : RMSE = 6.6139 ± 0.0435, MAE = 4.7762 ± 0.0294, R2 = 0.8713 ± 0.0017
#
# ==== Forecast of DST_PLUS6 ====
# ...

# %%
ace_adapted_cross_mlp_24, disc_train_24, disc_test_24, models_mlp = cross_adapt_domain(
    data_ace_24_copy,
    data_discover_24_copy,
    future_lags=future_lags,
    split_date=split_date,
    wind_model_type="MLP"
)

ace_adapted_cross_lgbm_24, disc_train_24, disc_test_24, models_lgbm = cross_adapt_domain(
    data_ace_24_copy,
    data_discover_24_copy,
    future_lags=future_lags,
    split_date=split_date,
    wind_model_type="LGBM"
)

# %%
ace_adapted_cross_mlp_af, disc_train_af, disc_test_af, models_mlp = cross_adapt_domain(
    data_ace_af_copy,
    data_discover_af_copy,
    future_lags=future_lags,
    split_date=split_date,
    wind_model_type="MLP"
)

ace_adapted_cross_lgbm_af, disc_train_af, disc_test_af, models_lgbm = cross_adapt_domain(
    data_ace_af_copy,
    data_discover_af_copy,
    future_lags=future_lags,
    split_date=split_date,
    wind_model_type="LGBM"
)

# %%
print("\n==== Mixed adaptation - MLP (fields linear, wind MLP) - 24h ====")
for target in targets:
    print(f"\n==== Forecast of {target.upper()} ====")
    df_all, df_sum, results_list = evaluate_M_D_with_error(
        ace_old_adapted=ace_adapted_cross_mlp_24,
        disc_train=disc_train_24,
        disc_test=disc_test_24,
        split_date=split_date,
        target=target,
        future_lags=future_lags,
        adaptation_method='ace-disc-cross-mlp',
        delays='24h',
        n_seeds=3,
        base_seed=42,
        results_list=results_list
    )

print("\n==== Mixed adaptation - LGBM (fields linear, wind LGBM) - 24h ====")
for target in targets:
    print(f"\n==== Forecast of {target.upper()} ====")
    df_all, df_sum, results_list = evaluate_M_D_with_error(
        ace_old_adapted=ace_adapted_cross_lgbm_24,
        disc_train=disc_train_24,
        disc_test=disc_test_24,
        split_date=split_date,
        target=target,
        future_lags=future_lags,
        adaptation_method='ace-disc-cross-lgbm',
        delays='24h',
        n_seeds=3,
        base_seed=42,
        results_list=results_list
    )
# Out:
# ==== Mixed adaptation - MLP (fields linear, wind MLP) - 24h ====
#
# ==== Forecast of DST_PLUS1 ====
# Linear  : RMSE = 3.2928 ± 0.0000, MAE = 2.3573 ± 0.0000, R2 = 0.9683 ± 0.0000
# Ridge   : RMSE = 3.2928 ± 0.0000, MAE = 2.3573 ± 0.0000, R2 = 0.9683 ± 0.0000
# Lasso   : RMSE = 3.2915 ± 0.0000, MAE = 2.3555 ± 0.0000, R2 = 0.9683 ± 0.0000
# LGBM    : RMSE = 3.4548 ± 0.0164, MAE = 2.3660 ± 0.0010, R2 = 0.9651 ± 0.0003
# MLP     : RMSE = 3.2654 ± 0.0299, MAE = 2.3580 ± 0.0119, R2 = 0.9688 ± 0.0006
#
# ==== Forecast of DST_PLUS3 ====
# Linear  : RMSE = 6.7200 ± 0.0000, MAE = 4.8347 ± 0.0000, R2 = 0.8677 ± 0.0000
# Ridge   : RMSE = 6.7199 ± 0.0000, MAE = 4.8347 ± 0.0000, R2 = 0.8677 ± 0.0000
# Lasso   : RMSE = 6.7132 ± 0.0000, MAE = 4.8294 ± 0.0000, R2 = 0.8680 ± 0.0000
# LGBM    : RMSE = 6.5372 ± 0.0135, MAE = 4.6867 ± 0.0070, R2 = 0.8748 ± 0.0005
# MLP     : RMSE = 6.5971 ± 0.0207, MAE = 4.7163 ± 0.0159, R2 = 0.8725 ± 0.0008
#
# ==== Forecast of DST_PLUS6 ====
# ...

# %%
print("\n==== Mixed adaptation - MLP (fields linear, wind MLP) - AF ====")
for target in targets:
    print(f"\n==== Forecast of {target.upper()} ====")
    df_all, df_sum, results_list = evaluate_M_D_with_error(
        ace_old_adapted=ace_adapted_cross_mlp_af,
        disc_train=disc_train_af,
        disc_test=disc_test_af,
        split_date=split_date,
        target=target,
        future_lags=future_lags,
        adaptation_method='ace-disc-cross-mlp',
        delays='auto_func',
        n_seeds=3,
        base_seed=42,
        results_list=results_list
    )

print("\n==== Mixed adaptation - LGBM (fields linear, wind LGBM) - AF ====")
for target in targets:
    print(f"\n==== Forecast of {target.upper()} ====")
    df_all, df_sum, results_list = evaluate_M_D_with_error(
        ace_old_adapted=ace_adapted_cross_lgbm_af,
        disc_train=disc_train_af,
        disc_test=disc_test_af,
        split_date=split_date,
        target=target,
        future_lags=future_lags,
        adaptation_method='ace-disc-cross-lgbm',
        delays='auto_func',
        n_seeds=3,
        base_seed=42,
        results_list=results_list
    )
# Out:
# ==== Mixed adaptation - MLP (fields linear, wind MLP) - AF ====
#
# ==== Forecast of DST_PLUS1 ====
# Linear  : RMSE = 3.2847 ± 0.0000, MAE = 2.3480 ± 0.0000, R2 = 0.9683 ± 0.0000
# Ridge   : RMSE = 3.2847 ± 0.0000, MAE = 2.3480 ± 0.0000, R2 = 0.9683 ± 0.0000
# Lasso   : RMSE = 3.2883 ± 0.0000, MAE = 2.3513 ± 0.0000, R2 = 0.9682 ± 0.0000
# LGBM    : RMSE = 3.3389 ± 0.0308, MAE = 2.3474 ± 0.0059, R2 = 0.9672 ± 0.0006
# MLP     : RMSE = 3.2182 ± 0.0309, MAE = 2.3289 ± 0.0279, R2 = 0.9695 ± 0.0006
#
# ==== Forecast of DST_PLUS3 ====
# Linear  : RMSE = 6.7542 ± 0.0000, MAE = 4.8695 ± 0.0000, R2 = 0.8658 ± 0.0000
# Ridge   : RMSE = 6.7542 ± 0.0000, MAE = 4.8695 ± 0.0000, R2 = 0.8658 ± 0.0000
# Lasso   : RMSE = 6.7508 ± 0.0000, MAE = 4.8659 ± 0.0000, R2 = 0.8659 ± 0.0000
# LGBM    : RMSE = 6.4731 ± 0.0242, MAE = 4.6751 ± 0.0126, R2 = 0.8767 ± 0.0009
# MLP     : RMSE = 6.5646 ± 0.0512, MAE = 4.7424 ± 0.0337, R2 = 0.8732 ± 0.0020
#
# ==== Forecast of DST_PLUS6 ====
# ...

# %%
results_df = pd.DataFrame(results_list)

# %%
results_df
# Out:
#         target     delays    adaptation_method forecast_model      RMSE  \
# 0    Dst_plus1        24h      ace-disc-linreg         Linear  3.311737
# 1    Dst_plus1        24h      ace-disc-linreg          Ridge  3.311645
# 2    Dst_plus1        24h      ace-disc-linreg          Lasso  3.312244
# 3    Dst_plus1        24h      ace-disc-linreg           LGBM  3.449495
# 4    Dst_plus1        24h      ace-disc-linreg            MLP  3.338102
# ..         ...        ...                  ...            ...       ...
# 145  Dst_plus6  auto_func  ace-disc-cross-lgbm         Linear  9.984372
# 146  Dst_plus6  auto_func  ace-disc-cross-lgbm          Ridge  9.984390
# 147  Dst_plus6  auto_func  ace-disc-cross-lgbm          Lasso  9.983728
# 148  Dst_plus6  auto_func  ace-disc-cross-lgbm           LGBM  9.720958
# 149  Dst_plus6  auto_func  ace-disc-cross-lgbm            MLP  9.895788
#
#      RMSE_std       MAE   MAE_std        R2    R2_std  n_seeds  base_seed
# ...

# %%
# results_df.to_excel("../results/models-adaptation-ace-to-discover_24-26 (заменить на верные cross-lgbm).xlsx", index=False)

# %%
# results_df.to_excel("../results/models-adaptation-ace-to-discover_24-26 (только cross-lgbm).xlsx", index=False)

# %%
results_df.to_excel("../results/models-adaptation-ace-to-discover_22-24.xlsx", index=False)
