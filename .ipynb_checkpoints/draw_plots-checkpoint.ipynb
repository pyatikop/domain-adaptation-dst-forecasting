# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df_no_adapt = pd.read_excel("../results/результаты.xlsx", sheet_name="без адаптации")
df_adapt_d_a = pd.read_excel("../results/результаты.xlsx", sheet_name="disc-ace")
df_adapt_a_d = pd.read_excel("../results/результаты.xlsx", sheet_name="ace-disc")

# %%
# df_adapt_a_d[df_adapt_a_d['adaptation_method'] == 'ace-disc-dann']

# %%
df = pd.concat([df_no_adapt, df_adapt_d_a, df_adapt_a_d], ignore_index=True)

df['scenario'][df['scenario'] == 'shuffle'] = 'комб.'
df['scenario'][df['scenario'] == 'ace-ace'] = 'A-A'
df['scenario'][df['scenario'] == 'ace-disc'] = 'A-D'
df['scenario'][df['scenario'] == 'disc-ace'] = 'D-A'
df['scenario'][df['scenario'] == 'disc-disc'] = 'D-D'

df['forecast_model'][df['forecast_model'] == 'Linear'] = 'ЛР'
df['forecast_model'][df['forecast_model'] == 'Ridge'] = 'ЛР L1'
df['forecast_model'][df['forecast_model'] == 'Lasso'] = 'ЛР L2'
df['forecast_model'][df['forecast_model'] == 'LGBM'] = 'ГБ'
df['forecast_model'][df['forecast_model'] == 'MLP'] = 'МСП'

df['adaptation_method'][df['adaptation_method'] == 'linreg'] = 'ЛР'
df['adaptation_method'][df['adaptation_method'] == 'lgbm'] = 'ГБ'
df['adaptation_method'][df['adaptation_method'] == 'pls'] = 'ПЛС'
df['adaptation_method'][df['adaptation_method'] == 'disc-ace-dann'] = 'D-A ДСНС'
df['adaptation_method'][df['adaptation_method'] == 'ace-disc-dann'] = 'A-D ДСНС'

df["adaptation_method"] = df["adaptation_method"].fillna("б/а")
df["scenario"] = df["scenario"].fillna("ДА")
df["scenario_adaptation"] = df["scenario"] + " " + df["adaptation_method"]

df['scenario_adaptation'].unique()
# df[df['adaptation_method'] == 'ace-disc-dann']
# Out:
# array(['A-A б/а', 'A-D б/а', 'D-A б/а', 'D-D б/а', 'комб. б/а', 'ДА ЛР',
#        'ДА ГБ', 'ДА ПЛС', 'ДА D-A ДСНС', 'ДА A-D ДСНС'], dtype=object)

# %%
df
# Out:
#         target delays scenario forecast_model       RMSE       MAE        R2  \
# 0    Dst_plus1    24h      A-A             ЛР   3.438899  2.401378  0.965960
# 1    Dst_plus1    24h      A-A          ЛР L1   3.439189  2.401620  0.965954
# 2    Dst_plus1    24h      A-A          ЛР L2   3.440365  2.401460  0.965931
# 3    Dst_plus1    24h      A-A             ГБ   4.088073  2.476720  0.951895
# 4    Dst_plus1    24h      A-A            МСП   3.735850  2.666253  0.959827
# ..         ...    ...      ...            ...        ...       ...       ...
# 555  Dst_plus6    24h       ДА             ЛР  10.555603  7.395713  0.678603
# 556  Dst_plus6    24h       ДА          ЛР L1  10.555326  7.395407  0.678620
# 557  Dst_plus6    24h       ДА          ЛР L2  10.549512  7.384339  0.678974
# 558  Dst_plus6    24h       ДА             ГБ  11.813897  7.421118  0.597411
# 559  Dst_plus6    24h       ДА            МСП  13.932380  9.112405  0.440080
#
#     adaptation_method scenario_adaptation
# 0                 б/а             A-A б/а
# 1                 б/а             A-A б/а
# 2                 б/а             A-A б/а
# 3                 б/а             A-A б/а
# 4                 б/а             A-A б/а
# ..                ...                 ...
# 555          A-D ДСНС         ДА A-D ДСНС
# 556          A-D ДСНС         ДА A-D ДСНС
# 557          A-D ДСНС         ДА A-D ДСНС
# 558          A-D ДСНС         ДА A-D ДСНС
# 559          A-D ДСНС         ДА A-D ДСНС
#
# [560 rows x 9 columns]

# %%
target_name = "Dst_plus1"
delays = 'auto_func'
# scenario = 'ace-ace'
forecast_model = "Lasso"

df_h_lin = df[(df["target"] == target_name) &
              (df["delays"] == delays) &
              (df["forecast_model"] == forecast_model)]
df_h_lin
# Out:
# Empty DataFrame
# Columns: [target, delays, scenario, forecast_model, RMSE, MAE, R2, adaptation_method, scenario_adaptation]
# Index: []

# %%
sns.set(style="whitegrid", font_scale=1.5)

target_name = "Dst_plus3"
delays = '24h'
forecast_model = "ЛР L2"

df_h_mod = df[(df["target"] == target_name) &
              (df["delays"] == delays) &
              (df["forecast_model"] == forecast_model)]

# df_h_mod[df_h_mod['scenario_adaptation'] == 'adapt - ace-disc-dann']

# print(df_h_mod[["scenario_adaptation", "forecast_model", "RMSE", "R2"]])

# #RMSE
# plt.figure(figsize=(12, 5))
# ax = sns.barplot(
#     data=df_h_mod,
#     x="scenario_adaptation",
#     y="RMSE",
#     ci=None
#     # hue="forecast_model"
# )

# plt.title("RMSE для прогнозов на 1 час")
# plt.ylabel("RMSE")
# plt.xlabel("Сценарий обучения без адаптации или модель адаптации / тип адаптации")
# plt.xticks(rotation=30, ha="right")

# for p in ax.patches:
#     height = p.get_height()
#     ax.annotate(f"{height:.2f}",
#                 (p.get_x() + p.get_width() / 2, height),
#                 ha="center", va="bottom",
#                 fontsize=8)

# plt.tight_layout()
# plt.show()

# %%
# R2
plt.figure(figsize=(12, 6))
ax = sns.barplot(
    data=df_h_mod,
    x="scenario_adaptation",
    y="R2",
    ci=None
    # hue="forecast_model"
)

plt.title("R² для прогнозов на 3 часа c помощью прогностической модели линейной регрессии с Lasso-регуляризацией")
plt.ylabel("R²")
plt.xlabel("Сценарий обучения / тип адаптации")
plt.xticks(rotation=30, ha="right")

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f"{height:.4f}",
                (p.get_x() + p.get_width() / 2, height),
                ha="center", va="bottom",
                fontsize=14)

plt.tight_layout()
# plt.ylim(0.91, 0.98)
# plt.ylim(0.6, 0.75)
plt.ylim(0.8, 0.89)
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.1)

hours_targets = ["Dst_plus1", "Dst_plus2", "Dst_plus3", "Dst_plus6"]

df_lin_multi = df[(df["target"].isin(hours_targets)) &
                  (df["forecast_model"] == "Linear")].copy()

df_lin_multi["target"] = pd.Categorical(
    df_lin_multi["target"],
    categories=hours_targets,
    ordered=True
)

plt.figure(figsize=(10, 5))
ax = sns.barplot(
    data=df_lin_multi,
    x="target",
    y="R2",
    hue="scenario_adaptation",
    palette="Blues",
    ci=None
)

plt.title("R² линейной модели для прогнозов на 1, 2, 3 и 6 часов")
plt.ylabel("R²")
plt.xlabel("Горизонт прогнозирования")
plt.xticks(rotation=0)

ax.grid(axis='y', linestyle='--', alpha=0.4)
ax.set_axisbelow(True)

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f"{height:.3f}",
                (p.get_x() + p.get_width() / 2, height + 0.002),
                ha="center", va="bottom",
                fontsize=9, rotation=90)

plt.ylim(0.6, 1.0)

ax.legend(
    title="scenario / adaptation",
    loc="upper center",
    bbox_to_anchor=(0.5, -0.15),
    ncol=4,
    frameon=True,
    fontsize=9,
    title_fontsize=10)

plt.tight_layout()
plt.show()

# %%
df_1h_dd_aa = df[(df["target"] == "Dst_plus3") &
                 (df["scenario_adaptation"].isin(["A-A б/а", "D-D б/а", 'комб. б/а',
                                                 'ДА ЛР', 'ДА ПЛС']))]

# все варианты
# ['A-A б/а', 'A-D б/а', 'D-A б/а', 'D-D б/а', 'комб. б/а', 'ДА ЛР',
# 'ДА ГБ', 'ДА ПЛС', 'ДА D-A ДСНС', 'ДА A-D ДСНС']

# print(df_1h_dd_aa[["scenario_adaptation", "RMSE", "R2"]])

# RMSE
# plt.figure(figsize=(10, 6))
# ax = sns.barplot(
#     data=df_1h_dd_aa,
#     x="forecast_model",
#     y="RMSE",
#     hue="scenario_adaptation",
#     ci=None
# )

# plt.title("RMSE для сценариев disc-disc и ace-ace, прогноз на 1 час")
# plt.ylabel("RMSE")
# plt.xlabel("Модель")
# plt.xticks(rotation=30, ha="right")

# for p in ax.patches:
#     height = p.get_height()
#     ax.annotate(f"{height:.2f}",
#                 (p.get_x() + p.get_width() / 2, height),
#                 ha="center", va="bottom",
#                 fontsize=9)

# plt.tight_layout()
# plt.ylim(3, 4)
# plt.show()

# R2
plt.figure(figsize=(10, 5))
ax = sns.barplot(
    data=df_1h_dd_aa,
    x="forecast_model",
    y="R2",
    hue="scenario_adaptation",
    palette="Blues",
    ci=None
)

plt.title("R² при прогнозе на 3 часа")
plt.ylabel("R²")
plt.xlabel("Модель прогнозирования")
# plt.xticks(rotation=30, ha="right")

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f"{height:.3f}",
                (p.get_x() + p.get_width() / 2, height + 0.004),
                ha="center", va="bottom",
                fontsize=10, rotation=90)

ax.legend(
    title="Сценарий обучения / тип адаптации",
    loc="upper center",
    bbox_to_anchor=(0.5, -0.18),
    ncol=6,
    frameon=True,
    fontsize=12,
    title_fontsize=12
)

plt.tight_layout()
# plt.ylim(0.9, 0.98)
# plt.ylim(0.5, 0.75)
plt.ylim(0.78, 0.89)
plt.show()
