# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor
from lightgbm import LGBMRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data_ace_24 = pd.read_csv("../data/Ace_погружение_24часа.csv", sep=';', decimal=',', parse_dates=['datetime'], index_col='datetime')
data_discover_24 = pd.read_csv("../data/Discover_погружение_24часа.csv", sep=';', decimal=',', parse_dates=['datetime'], index_col='datetime')
data_ace_af = pd.read_csv("../data/Ace_погружение_AF.csv", sep=';', decimal=',', parse_dates=['datetime'], index_col='datetime')
data_discover_af = pd.read_csv("../data/Discover_погружение_AF.csv", sep=';', decimal=',', parse_dates=['datetime'], index_col='datetime')

# %%
def split_datasets_intersection(ace, disc, split_date, scenario):
    """
    Разделяет два датасета ace и discover на train/test по заданной дате split_date.
    При необходимости выравнивает временные индексы (пересечение) и удаляет строки с NaN.

    Сценарии:
    1. 'ace-ace'   — обучение и тестирование на ACE (train до split_date, test после)
    2. 'ace-disc'  — обучение на ACE (до split_date), тестирование на DISC (после split_date)
    3. 'disc-ace'  — обучение на DISC (до split_date), тестирование на ACE (после split_date)
    4. 'disc-disc' — обучение и тестирование на DISC (train до split_date, test после)
    """
    a = ace.copy()
    d = disc.copy()

    # Выравниваем временные индексы так, чтобы все наборы были на одинаковых данных в пересечениях
    common_idx = a.index.intersection(d.index)
    a = a.loc[common_idx].dropna(axis=0, how='any')
    d = d.loc[common_idx].dropna(axis=0, how='any')

    # Дата разделения
    split_date = pd.Timestamp(split_date)

    # Сценарии
    if scenario == 'ace-ace':
        train = a[a.index < split_date].copy()
        test  = a[a.index >= split_date].copy()

    elif scenario == 'ace-disc':
        train = a[a.index < split_date].copy()
        test  = d[d.index >= split_date].copy()

    elif scenario == 'disc-ace':
        train = d[d.index < split_date].copy()
        test  = a[a.index >= split_date].copy()

    elif scenario == 'disc-disc':
        train = d[d.index < split_date].copy()
        test  = d[d.index >= split_date].copy()

    else:
        raise ValueError(f"Некорректный сценарий '{scenario}'. "
                         f"Должен быть один из: 'ace-ace', 'ace-disc', 'disc-ace', 'disc-disc'")

    return train, test

# %%
def build_models(random_state=42):
    models = {}
    models['Linear'] = Pipeline([
        ("scaler", StandardScaler()),
        ("lin", LinearRegression())
    ])
    
    models['Ridge'] = Pipeline([
        ("scaler", StandardScaler()),
        ("ridge", Ridge(
            alpha=1.0,
            solver='auto',
            random_state=random_state))
    ])

    models['Lasso'] = Pipeline([
        ("scaler", StandardScaler()),
        ("lasso", Lasso(
            alpha=0.0005,
            tol=0.01,
            max_iter=500, 
            random_state=random_state))
    ])
    
    models['LGBM'] = Pipeline([
        ("boost", LGBMRegressor(
            n_estimators=1500,
            max_depth=3,
            early_stopping_rounds=50,
            random_state=random_state,
            verbose=-1))
    ])
    
    models['MLP'] = Pipeline([
        ("scaler", StandardScaler()),
        ("mlp", MLPRegressor(
            hidden_layer_sizes=(256, 256, 128),
            solver='adam',
            alpha=1e-4,
            learning_rate_init=1e-3,
            early_stopping=True,
            validation_fraction=0.1,
            max_iter=1500,
            random_state=random_state))
    ])
    return models
    
models = build_models()

def evaluate_models(ace, disc, split_date, target, future_lags, scenario='ace-ace', delays='24h', results_list=None):
    """
    Обучает все модели на train/test наборах, полученных из split_datasets_intersection(),
    и вычисляет метрики mse и r2_score
    """
    # Разделяем данные по сценарию
    train, test = split_datasets_intersection(ace, disc, split_date, scenario=scenario)
        
    # Определение признаков (здесь убираю из признаков все значения dst+1, dst+2, dst+3,...)
    feature_cols = [c for c in train.columns if c not in future_lags]

    train = train.dropna(subset=feature_cols + [target])
    test = test.dropna(subset=feature_cols + [target])

    X_train, y_train = train[feature_cols].values, train[target].values
    X_test, y_test = test[feature_cols].values, test[target].values

    if results_list is None:
        results_list = []

    print(f"\n=== {scenario.upper()} ===")
    for name, model in models.items():
        try:
            if name == 'LGBM':
                # Для бустинга выделяем валидационный набор
                X_tr, X_val, y_tr, y_val = train_test_split(
                    X_train, y_train, test_size=0.1, random_state=42)
                model.fit(
                    X_tr, y_tr,
                    boost__eval_set=[(X_val, y_val)],
                    boost__eval_metric='l2')
            else:
                model.fit(X_train, y_train)

            y_pred = model.predict(X_test)

            rmse = np.sqrt(mean_squared_error(y_test, y_pred))
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            results_list.append({
                'target': target,
                'delays': delays,
                'scenario': scenario,
                'forecast_model': name,
                'RMSE': rmse,
                'MAE': mae,
                'R2': r2
            })

            print(f"{name}: rmse={rmse:.4f}, mae={mae:.4f}, r2={r2:.4f}")

        except Exception as e:
            print(f"{name:10s} -> Ошибка обучения: {e}")

    return results_list

# %%
def models_shuffle(ace_df, disc_df, split_date, target, future_lags, scenario='shuffle', delays='24h', results_list=None):
    """
    Объединяет данные ace и discover, добавляет признак is_ace,
    разделяет на train/test по дате и обучает модели.
    """
    ace = ace_df.sort_index()
    disc = disc_df.sort_index()

    split_date = pd.Timestamp(split_date)
    
    ace['is_ace'] = 1
    disc['is_ace'] = 0

    ace_train = ace.loc[:split_date]
    ace_test = ace.loc[split_date:]
    
    disc_train = disc.loc[:split_date]
    disc_test = disc.loc[split_date:]

    split_date = pd.Timestamp(split_date)
    
    combined_train = pd.concat([ace_train, disc_train], ignore_index=False)
    combined_train = combined_train.sort_values('datetime')
    
    feature_cols = [c for c in ace_train.columns if c not in future_lags]
    
    train = combined_train.dropna(subset=feature_cols + [target])
    test = disc_test.dropna(subset=feature_cols + [target])

    X_train, y_train = train[feature_cols].values, train[target].values
    X_test, y_test = test[feature_cols].values, test[target].values
    
    if results_list is None:
        results_list = []

    print(f"\n=== {scenario.upper()} ===")
    for name, model in models.items():
        try:
            if name == 'LGBM':
                # Для бустинга выделяем валидационный набор
                X_tr, X_val, y_tr, y_val = train_test_split(
                    X_train, y_train, test_size=0.1, random_state=42)
                model.fit(
                    X_tr, y_tr,
                    boost__eval_set=[(X_val, y_val)],
                    boost__eval_metric='l2')
            else:
                model.fit(X_train, y_train)

            y_pred = model.predict(X_test)
                   
            rmse = np.sqrt(mean_squared_error(y_test, y_pred))
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            results_list.append({
                'target': target,
                'delays': delays,
                'scenario': scenario,
                'forecast_model': name,
                'RMSE': rmse,
                'MAE': mae,
                'R2': r2
            })

            print(f"{name}: rmse={rmse:.4f}, mae={mae:.4f}, r2={r2:.4f}")

        except Exception as e:
            print(f"{name:10s} -> Ошибка обучения: {e}")

    return results_list

# %%
# 0. Копирование загруженных данных в отдельные переменные
data_ace_24_copy = data_ace_24.copy()
data_discover_24_copy = data_discover_24.copy()
data_ace_af_copy = data_ace_af.copy()
data_discover_af_copy = data_discover_af.copy()

# 1. Задание переменных для обучения
split_date = "2022-01-01" # дата по которой происходит разбиение данных на тренировочный и тестовый наборы
scenarios = ['ace-ace', 'ace-disc', 'disc-ace', 'disc-disc']
future_lags = [f'Dst_plus{i}' for i in range(1, 25)] # все сдвиги во времени вперед (задаются при обработке данных)
targets = ['Dst_plus1', 'Dst_plus2', 'Dst_plus3', 'Dst_plus6', 'Dst_plus12', 'Dst_plus24'] # таргеты, на которые делаем прогнозы

results_list = []

# %%
# 2. Обучение для датасетов с глубиной - 24 часа по всем переменным
print(f"\n==== Depth - 24h ====")
for target_col in targets:
    print(f"\n==== Forecast of {target_col.upper()} ====")
    for scen in scenarios:
        res = evaluate_models(data_ace_24_copy, data_discover_24_copy, split_date, target_col, future_lags, scenario=scen, delays='24h', results_list=results_list)
# Out:
# ==== Depth - 24h ====
#
# ==== Forecast of DST_PLUS1 ====
#
# === ACE-ACE ===
# Linear: rmse=3.4389, mae=2.4014, r2=0.9660
# Ridge: rmse=3.4392, mae=2.4016, r2=0.9660
# Lasso: rmse=3.4404, mae=2.4015, r2=0.9659
# LGBM: rmse=4.0881, mae=2.4767, r2=0.9519
# MLP: rmse=3.7359, mae=2.6663, r2=0.9598
#
# === ACE-DISC ===
# Linear: rmse=3.5907, mae=2.5339, r2=0.9629
# Ridge: rmse=3.5905, mae=2.5337, r2=0.9629
# Lasso: rmse=3.5705, mae=2.5159, r2=0.9633
# LGBM: rmse=4.1909, mae=2.6573, r2=0.9494
# MLP: rmse=4.3954, mae=3.1858, r2=0.9444
#
# === DISC-ACE ===
# Linear: rmse=3.4542, mae=2.4098, r2=0.9657
# Ridge: rmse=3.4545, mae=2.4101, r2=0.9657
# Lasso: rmse=3.4559, mae=2.4111, r2=0.9656
# LGBM: rmse=4.1613, mae=2.5163, r2=0.9502
# MLP: rmse=3.7084, mae=2.6433, r2=0.9604
#
# === DISC-DISC ===
# Linear: rmse=3.3877, mae=2.3860, r2=0.9670
# Ridge: rmse=3.3879, mae=2.3862, r2=0.9670
# Lasso: rmse=3.3886, mae=2.3863, r2=0.9669
# LGBM: rmse=4.0299, mae=2.4878, r2=0.9533
# MLP: rmse=3.7324, mae=2.6650, r2=0.9599
#
# ==== Forecast of DST_PLUS2 ====
#
# === ACE-ACE ===
# Linear: rmse=5.4509, mae=3.8452, r2=0.9144
# Ridge: rmse=5.4511, mae=3.8453, r2=0.9144
# Lasso: rmse=5.4504, mae=3.8447, r2=0.9145
# LGBM: rmse=5.9053, mae=3.8345, r2=0.8996
# MLP: rmse=6.2344, mae=4.4887, r2=0.8881
#
# === ACE-DISC ===
# Linear: rmse=5.5943, mae=3.9706, r2=0.9099
# Ridge: rmse=5.5942, mae=3.9705, r2=0.9099
# Lasso: rmse=5.5850, mae=3.9622, r2=0.9102
# LGBM: rmse=6.2023, mae=4.1948, r2=0.8892
# MLP: rmse=7.2929, mae=5.3371, r2=0.8468
#
# === DISC-ACE ===
# Linear: rmse=5.4537, mae=3.8402, r2=0.9144
# Ridge: rmse=5.4539, mae=3.8403, r2=0.9143
# Lasso: rmse=5.4535, mae=3.8399, r2=0.9144
# LGBM: rmse=5.9156, mae=3.8651, r2=0.8992
# MLP: rmse=6.4822, mae=4.7174, r2=0.8790
#
# === DISC-DISC ===
# Linear: rmse=5.3835, mae=3.8063, r2=0.9165
# Ridge: rmse=5.3836, mae=3.8064, r2=0.9165
# Lasso: rmse=5.3831, mae=3.8061, r2=0.9166
# LGBM: rmse=5.6850, mae=3.7997, r2=0.9069
# MLP: rmse=6.4526, mae=4.7384, r2=0.8801
#
# ==== Forecast of DST_PLUS3 ====
#
# === ACE-ACE ===
# Linear: rmse=6.9885, mae=4.9105, r2=0.8593
# Ridge: rmse=6.9886, mae=4.9105, r2=0.8593
# Lasso: rmse=6.9878, mae=4.9098, r2=0.8593
# LGBM: rmse=7.4627, mae=4.9116, r2=0.8396
# MLP: rmse=8.2777, mae=5.9361, r2=0.8026
#
# === ACE-DISC ===
# Linear: rmse=7.1957, mae=5.0961, r2=0.8508
# Ridge: rmse=7.1958, mae=5.0961, r2=0.8508
# Lasso: rmse=7.1894, mae=5.0904, r2=0.8511
# LGBM: rmse=7.8682, mae=5.4105, r2=0.8217
# MLP: rmse=9.5012, mae=6.9005, r2=0.7399
#
# === DISC-ACE ===
# Linear: rmse=6.9908, mae=4.8836, r2=0.8592
# Ridge: rmse=6.9909, mae=4.8837, r2=0.8592
# Lasso: rmse=6.9900, mae=4.8829, r2=0.8592
# LGBM: rmse=7.3123, mae=4.8932, r2=0.8460
# MLP: rmse=8.4125, mae=6.0209, r2=0.7961
#
# === DISC-DISC ===
# Linear: rmse=6.9342, mae=4.8656, r2=0.8615
# Ridge: rmse=6.9343, mae=4.8656, r2=0.8615
# Lasso: rmse=6.9335, mae=4.8652, r2=0.8615
# LGBM: rmse=7.0991, mae=4.8212, r2=0.8548
# MLP: rmse=8.3849, mae=6.0936, r2=0.7975
#
# ==== Forecast of DST_PLUS6 ====
#
# === ACE-ACE ===
# Linear: rmse=10.1654, mae=6.9103, r2=0.7019
# Ridge: rmse=10.1655, mae=6.9104, r2=0.7019
# Lasso: rmse=10.1651, mae=6.9099, r2=0.7019
# LGBM: rmse=10.6819, mae=7.1278, r2=0.6709
# MLP: rmse=11.7249, mae=8.1805, r2=0.6035
#
# === ACE-DISC ===
# Linear: rmse=10.8444, mae=7.6756, r2=0.6608
# Ridge: rmse=10.8447, mae=7.6759, r2=0.6608
# Lasso: rmse=10.8455, mae=7.6776, r2=0.6607
# LGBM: rmse=11.2421, mae=7.8098, r2=0.6354
# MLP: rmse=14.3332, mae=10.2766, r2=0.4074
#
# === DISC-ACE ===
# Linear: rmse=10.2088, mae=6.8287, r2=0.6994
# Ridge: rmse=10.2089, mae=6.8287, r2=0.6994
# Lasso: rmse=10.2084, mae=6.8281, r2=0.6994
# LGBM: rmse=10.7714, mae=7.1247, r2=0.6653
# MLP: rmse=11.8077, mae=8.1092, r2=0.5978
#
# === DISC-DISC ===
# Linear: rmse=10.1770, mae=6.9284, r2=0.7012
# Ridge: rmse=10.1771, mae=6.9285, r2=0.7012
# Lasso: rmse=10.1765, mae=6.9279, r2=0.7013
# LGBM: rmse=10.5734, mae=7.0928, r2=0.6775
# MLP: rmse=11.7914, mae=8.2168, r2=0.5989
#
# ==== Forecast of DST_PLUS12 ====
#
# === ACE-ACE ===
# Linear: rmse=13.5256, mae=8.8480, r2=0.4711
# Ridge: rmse=13.5256, mae=8.8480, r2=0.4711
# Lasso: rmse=13.5253, mae=8.8474, r2=0.4711
# LGBM: rmse=13.9908, mae=9.1269, r2=0.4341
# MLP: rmse=14.9634, mae=10.0842, r2=0.3527
#
# === ACE-DISC ===
# Linear: rmse=14.9072, mae=10.5031, r2=0.3575
# Ridge: rmse=14.9076, mae=10.5035, r2=0.3575
# Lasso: rmse=14.9072, mae=10.5031, r2=0.3575
# LGBM: rmse=15.5892, mae=10.8725, r2=0.2974
# MLP: rmse=16.9247, mae=12.1552, r2=0.1719
#
# === DISC-ACE ===
# Linear: rmse=13.6742, mae=8.7314, r2=0.4594
# Ridge: rmse=13.6742, mae=8.7314, r2=0.4594
# Lasso: rmse=13.6735, mae=8.7306, r2=0.4595
# LGBM: rmse=14.3402, mae=9.1739, r2=0.4055
# MLP: rmse=15.5498, mae=10.5952, r2=0.3010
#
# === DISC-DISC ===
# Linear: rmse=13.5481, mae=8.9285, r2=0.4693
# Ridge: rmse=13.5482, mae=8.9285, r2=0.4693
# Lasso: rmse=13.5477, mae=8.9280, r2=0.4694
# LGBM: rmse=14.0172, mae=9.1742, r2=0.4320
# MLP: rmse=15.0828, mae=10.2572, r2=0.3423
#
# ==== Forecast of DST_PLUS24 ====
#
# === ACE-ACE ===
# Linear: rmse=16.3412, mae=10.3629, r2=0.2271
# Ridge: rmse=16.3412, mae=10.3629, r2=0.2271
# Lasso: rmse=16.3402, mae=10.3623, r2=0.2272
# LGBM: rmse=16.7135, mae=10.7068, r2=0.1915
# MLP: rmse=17.6743, mae=11.7653, r2=0.0959
#
# === ACE-DISC ===
# Linear: rmse=17.1870, mae=11.8835, r2=0.1450
# Ridge: rmse=17.1874, mae=11.8840, r2=0.1450
# Lasso: rmse=17.1856, mae=11.8831, r2=0.1452
# LGBM: rmse=19.1485, mae=13.7180, r2=-0.0613
# MLP: rmse=19.9310, mae=14.2531, r2=-0.1498
#
# === DISC-ACE ===
# Linear: rmse=16.6366, mae=10.2733, r2=0.1989
# Ridge: rmse=16.6366, mae=10.2733, r2=0.1989
# Lasso: rmse=16.6357, mae=10.2727, r2=0.1990
# LGBM: rmse=17.3215, mae=10.9239, r2=0.1316
# MLP: rmse=18.1661, mae=12.0216, r2=0.0448
#
# === DISC-DISC ===
# Linear: rmse=16.3076, mae=10.4401, r2=0.2303
# Ridge: rmse=16.3076, mae=10.4401, r2=0.2303
# Lasso: rmse=16.3069, mae=10.4397, r2=0.2304
# LGBM: rmse=16.8962, mae=10.8857, r2=0.1737
# MLP: rmse=17.9348, mae=12.0498, r2=0.0690

# %%
# 3. Обучение для датасетов с глубиной, заданной автокорреляционной функцией
print(f"\n==== Depth - autocorrelation function ====")
for target_col in targets:
    print(f"\n==== Forecast of {target_col.upper()} ====")
    for scen in scenarios:
        res = evaluate_models(data_ace_af_copy, data_discover_af_copy, split_date, target_col, future_lags, scenario=scen, delays='auto_func', results_list=results_list)
# Out:
# ==== Depth - autocorrelation function ====
#
# ==== Forecast of DST_PLUS1 ====
#
# === ACE-ACE ===
# Linear: rmse=3.4396, mae=2.4041, r2=0.9658
# Ridge: rmse=3.4399, mae=2.4043, r2=0.9658
# Lasso: rmse=3.4424, mae=2.4053, r2=0.9657
# LGBM: rmse=4.1194, mae=2.4906, r2=0.9509
# MLP: rmse=3.6414, mae=2.6011, r2=0.9616
#
# === ACE-DISC ===
# Linear: rmse=3.5923, mae=2.5341, r2=0.9627
# Ridge: rmse=3.5922, mae=2.5339, r2=0.9627
# Lasso: rmse=3.5747, mae=2.5181, r2=0.9630
# LGBM: rmse=4.2961, mae=2.7281, r2=0.9466
# MLP: rmse=4.6049, mae=3.2366, r2=0.9387
#
# === DISC-ACE ===
# Linear: rmse=3.4636, mae=2.4255, r2=0.9653
# Ridge: rmse=3.4639, mae=2.4257, r2=0.9653
# Lasso: rmse=3.4661, mae=2.4276, r2=0.9652
# LGBM: rmse=4.1324, mae=2.5027, r2=0.9506
# MLP: rmse=3.7184, mae=2.7056, r2=0.9600
#
# === DISC-DISC ===
# Linear: rmse=3.3922, mae=2.3925, r2=0.9667
# Ridge: rmse=3.3924, mae=2.3926, r2=0.9667
# Lasso: rmse=3.3937, mae=2.3932, r2=0.9667
# LGBM: rmse=3.9968, mae=2.4816, r2=0.9538
# MLP: rmse=3.6315, mae=2.6380, r2=0.9618
#
# ==== Forecast of DST_PLUS2 ====
#
# === ACE-ACE ===
# Linear: rmse=5.4636, mae=3.8671, r2=0.9136
# Ridge: rmse=5.4638, mae=3.8672, r2=0.9136
# Lasso: rmse=5.4638, mae=3.8670, r2=0.9136
# LGBM: rmse=5.9440, mae=3.8674, r2=0.8978
# MLP: rmse=6.5215, mae=4.7470, r2=0.8770
#
# === ACE-DISC ===
# Linear: rmse=5.5991, mae=3.9740, r2=0.9093
# Ridge: rmse=5.5990, mae=3.9739, r2=0.9093
# Lasso: rmse=5.5907, mae=3.9662, r2=0.9096
# LGBM: rmse=6.3176, mae=4.3101, r2=0.8845
# MLP: rmse=7.6757, mae=5.6595, r2=0.8295
#
# === DISC-ACE ===
# Linear: rmse=5.4710, mae=3.8745, r2=0.9134
# Ridge: rmse=5.4711, mae=3.8746, r2=0.9134
# Lasso: rmse=5.4713, mae=3.8746, r2=0.9134
# LGBM: rmse=5.9038, mae=3.9038, r2=0.8992
# MLP: rmse=6.3598, mae=4.6004, r2=0.8830
#
# === DISC-DISC ===
# Linear: rmse=5.4006, mae=3.8324, r2=0.9156
# Ridge: rmse=5.4007, mae=3.8325, r2=0.9156
# Lasso: rmse=5.4006, mae=3.8325, r2=0.9156
# LGBM: rmse=5.7086, mae=3.8551, r2=0.9057
# MLP: rmse=6.3445, mae=4.6549, r2=0.8835
#
# ==== Forecast of DST_PLUS3 ====
#
# === ACE-ACE ===
# Linear: rmse=7.0028, mae=4.9344, r2=0.8581
# Ridge: rmse=7.0030, mae=4.9345, r2=0.8581
# Lasso: rmse=7.0031, mae=4.9345, r2=0.8581
# LGBM: rmse=7.4080, mae=4.9213, r2=0.8412
# MLP: rmse=8.5580, mae=6.1280, r2=0.7881
#
# === ACE-DISC ===
# Linear: rmse=7.1912, mae=5.0884, r2=0.8504
# Ridge: rmse=7.1913, mae=5.0884, r2=0.8504
# Lasso: rmse=7.1834, mae=5.0821, r2=0.8507
# LGBM: rmse=7.9833, mae=5.5724, r2=0.8156
# MLP: rmse=10.9255, mae=7.8011, r2=0.6546
#
# === DISC-ACE ===
# Linear: rmse=6.9981, mae=4.9204, r2=0.8583
# Ridge: rmse=6.9982, mae=4.9205, r2=0.8583
# Lasso: rmse=6.9979, mae=4.9200, r2=0.8583
# LGBM: rmse=7.4198, mae=4.9609, r2=0.8407
# MLP: rmse=8.3621, mae=6.0243, r2=0.7977
#
# === DISC-DISC ===
# Linear: rmse=6.9567, mae=4.9039, r2=0.8600
# Ridge: rmse=6.9568, mae=4.9040, r2=0.8600
# Lasso: rmse=6.9563, mae=4.9034, r2=0.8600
# LGBM: rmse=7.2053, mae=4.9119, r2=0.8498
# MLP: rmse=8.3186, mae=6.0525, r2=0.7998
#
# ==== Forecast of DST_PLUS6 ====
#
# === ACE-ACE ===
# Linear: rmse=10.1586, mae=6.9425, r2=0.7015
# Ridge: rmse=10.1587, mae=6.9425, r2=0.7014
# Lasso: rmse=10.1589, mae=6.9422, r2=0.7014
# LGBM: rmse=10.6029, mae=7.1285, r2=0.6748
# MLP: rmse=11.8273, mae=8.2371, r2=0.5953
#
# === ACE-DISC ===
# Linear: rmse=10.7969, mae=7.6651, r2=0.6628
# Ridge: rmse=10.7972, mae=7.6654, r2=0.6627
# Lasso: rmse=10.7937, mae=7.6620, r2=0.6630
# LGBM: rmse=11.4925, mae=8.1418, r2=0.6179
# MLP: rmse=14.1226, mae=10.0740, r2=0.4230
#
# === DISC-ACE ===
# Linear: rmse=10.1600, mae=6.8567, r2=0.7014
# Ridge: rmse=10.1601, mae=6.8567, r2=0.7014
# Lasso: rmse=10.1600, mae=6.8565, r2=0.7014
# LGBM: rmse=10.7830, mae=7.1817, r2=0.6636
# MLP: rmse=11.9908, mae=8.3402, r2=0.5841
#
# === DISC-DISC ===
# Linear: rmse=10.1872, mae=6.9966, r2=0.6998
# Ridge: rmse=10.1873, mae=6.9966, r2=0.6998
# Lasso: rmse=10.1871, mae=6.9964, r2=0.6998
# LGBM: rmse=10.6951, mae=7.1957, r2=0.6691
# MLP: rmse=11.9594, mae=8.3672, r2=0.5862
#
# ==== Forecast of DST_PLUS12 ====
#
# === ACE-ACE ===
# Linear: rmse=13.4781, mae=8.8502, r2=0.4746
# Ridge: rmse=13.4781, mae=8.8503, r2=0.4746
# Lasso: rmse=13.4782, mae=8.8499, r2=0.4746
# LGBM: rmse=14.0075, mae=9.1739, r2=0.4325
# MLP: rmse=15.0189, mae=10.1237, r2=0.3476
#
# === ACE-DISC ===
# Linear: rmse=14.7880, mae=10.4150, r2=0.3675
# Ridge: rmse=14.7884, mae=10.4154, r2=0.3674
# Lasso: rmse=14.7859, mae=10.4130, r2=0.3677
# LGBM: rmse=15.9633, mae=11.3154, r2=0.2629
# MLP: rmse=16.9000, mae=11.9186, r2=0.1739
#
# === DISC-ACE ===
# Linear: rmse=13.5509, mae=8.7036, r2=0.4689
# Ridge: rmse=13.5510, mae=8.7036, r2=0.4689
# Lasso: rmse=13.5508, mae=8.7032, r2=0.4689
# LGBM: rmse=14.1794, mae=9.0654, r2=0.4185
# MLP: rmse=15.8630, mae=10.5754, r2=0.2722
#
# === DISC-DISC ===
# Linear: rmse=13.5155, mae=8.9587, r2=0.4717
# Ridge: rmse=13.5155, mae=8.9587, r2=0.4717
# Lasso: rmse=13.5155, mae=8.9586, r2=0.4717
# LGBM: rmse=14.0882, mae=9.2609, r2=0.4259
# MLP: rmse=15.4713, mae=10.3970, r2=0.3077
#
# ==== Forecast of DST_PLUS24 ====
#
# === ACE-ACE ===
# Linear: rmse=16.3285, mae=10.3748, r2=0.2287
# Ridge: rmse=16.3284, mae=10.3748, r2=0.2287
# Lasso: rmse=16.3280, mae=10.3747, r2=0.2287
# LGBM: rmse=16.8198, mae=10.7715, r2=0.1816
# MLP: rmse=17.6714, mae=11.6897, r2=0.0966
#
# === ACE-DISC ===
# Linear: rmse=17.0589, mae=11.6684, r2=0.1581
# Ridge: rmse=17.0592, mae=11.6688, r2=0.1581
# Lasso: rmse=17.0562, mae=11.6652, r2=0.1584
# LGBM: rmse=19.6975, mae=14.1392, r2=-0.1225
# MLP: rmse=22.0736, mae=15.9012, r2=-0.4096
#
# === DISC-ACE ===
# Linear: rmse=16.5607, mae=10.2448, r2=0.2066
# Ridge: rmse=16.5607, mae=10.2447, r2=0.2066
# Lasso: rmse=16.5600, mae=10.2445, r2=0.2066
# LGBM: rmse=17.2182, mae=10.8367, r2=0.1423
# MLP: rmse=18.0459, mae=11.8102, r2=0.0579
#
# === DISC-DISC ===
# Linear: rmse=16.3031, mae=10.4725, r2=0.2311
# Ridge: rmse=16.3030, mae=10.4725, r2=0.2311
# Lasso: rmse=16.3025, mae=10.4723, r2=0.2311
# LGBM: rmse=16.9408, mae=11.0137, r2=0.1697
# MLP: rmse=17.9703, mae=12.0333, r2=0.0658

# %%
# 4. Предсказание на перемешанных данных с признаком is_ace
print(f"\n==== Depth - 24h ====")
for target_col in targets:
    print(f"\n==== Forecast of {target_col.upper()} ====")
    res = models_shuffle(data_ace_24_copy, data_discover_24_copy, split_date, target_col, future_lags, scenario='shuffle', delays='24h', results_list=results_list)

print(f"\n==== Depth - autocorrelation function ====")
for target_col in targets:
    print(f"\n==== Forecast of {target_col.upper()} ====")
    res = models_shuffle(data_ace_af_copy, data_discover_af_copy, split_date, target_col, future_lags, scenario='shuffle', delays='auto_func', results_list=results_list)
# Out:
# ==== Depth - 24h ====
#
# ==== Forecast of DST_PLUS1 ====
#
# === SHUFFLE ===
# Linear: rmse=3.3808, mae=2.4058, r2=0.9671
# Ridge: rmse=3.3808, mae=2.4057, r2=0.9671
# Lasso: rmse=3.3775, mae=2.4020, r2=0.9672
# LGBM: rmse=3.4319, mae=2.3563, r2=0.9661
# MLP: rmse=3.4934, mae=2.5104, r2=0.9649
#
# ==== Forecast of DST_PLUS2 ====
#
# === SHUFFLE ===
# Linear: rmse=5.2853, mae=3.8044, r2=0.9196
# Ridge: rmse=5.2853, mae=3.8044, r2=0.9196
# Lasso: rmse=5.2839, mae=3.8029, r2=0.9196
# LGBM: rmse=5.0668, mae=3.6047, r2=0.9261
# MLP: rmse=5.5948, mae=4.0409, r2=0.9099
#
# ==== Forecast of DST_PLUS3 ====
#
# === SHUFFLE ===
# Linear: rmse=6.7741, mae=4.8640, r2=0.8678
# Ridge: rmse=6.7741, mae=4.8640, r2=0.8678
# Lasso: rmse=6.7730, mae=4.8626, r2=0.8678
# LGBM: rmse=6.5237, mae=4.6064, r2=0.8774
# MLP: rmse=8.0431, mae=5.7519, r2=0.8136
#
# ==== Forecast of DST_PLUS6 ====
#
# === SHUFFLE ===
# Linear: rmse=10.0001, mae=6.9663, r2=0.7115
# Ridge: rmse=10.0001, mae=6.9663, r2=0.7115
# Lasso: rmse=10.0001, mae=6.9661, r2=0.7115
# LGBM: rmse=9.9325, mae=6.8095, r2=0.7154
# MLP: rmse=12.2752, mae=8.6107, r2=0.5654
#
# ==== Forecast of DST_PLUS12 ====
#
# === SHUFFLE ===
# Linear: rmse=13.5215, mae=9.0649, r2=0.4714
# Ridge: rmse=13.5215, mae=9.0649, r2=0.4714
# Lasso: rmse=13.5209, mae=9.0644, r2=0.4715
# LGBM: rmse=13.6818, mae=8.9771, r2=0.4588
# MLP: rmse=15.6751, mae=10.7533, r2=0.2896
#
# ==== Forecast of DST_PLUS24 ====
#
# === SHUFFLE ===
# Linear: rmse=16.3132, mae=10.6067, r2=0.2298
# Ridge: rmse=16.3132, mae=10.6067, r2=0.2298
# Lasso: rmse=16.3127, mae=10.6068, r2=0.2298
# LGBM: rmse=16.3244, mae=10.5474, r2=0.2287
# MLP: rmse=19.4418, mae=13.2651, r2=-0.0940
#
# ==== Depth - autocorrelation function ====
#
# ==== Forecast of DST_PLUS1 ====
#
# === SHUFFLE ===
# Linear: rmse=3.3922, mae=2.4148, r2=0.9667
# Ridge: rmse=3.3921, mae=2.4148, r2=0.9667
# Lasso: rmse=3.3889, mae=2.4112, r2=0.9668
# LGBM: rmse=3.4143, mae=2.3585, r2=0.9663
# MLP: rmse=3.4778, mae=2.4974, r2=0.9650
#
# ==== Forecast of DST_PLUS2 ====
#
# === SHUFFLE ===
# Linear: rmse=5.3223, mae=3.8387, r2=0.9180
# Ridge: rmse=5.3222, mae=3.8387, r2=0.9180
# Lasso: rmse=5.3207, mae=3.8374, r2=0.9181
# LGBM: rmse=5.0766, mae=3.6376, r2=0.9254
# MLP: rmse=5.7235, mae=4.1168, r2=0.9052
#
# ==== Forecast of DST_PLUS3 ====
#
# === SHUFFLE ===
# Linear: rmse=6.8226, mae=4.9086, r2=0.8653
# Ridge: rmse=6.8226, mae=4.9086, r2=0.8653
# Lasso: rmse=6.8210, mae=4.9068, r2=0.8654
# LGBM: rmse=6.5859, mae=4.6626, r2=0.8745
# MLP: rmse=8.0677, mae=5.8662, r2=0.8117
#
# ==== Forecast of DST_PLUS6 ====
#
# === SHUFFLE ===
# Linear: rmse=10.0316, mae=7.0204, r2=0.7089
# Ridge: rmse=10.0317, mae=7.0204, r2=0.7089
# Lasso: rmse=10.0316, mae=7.0203, r2=0.7089
# LGBM: rmse=9.9646, mae=6.8436, r2=0.7128
# MLP: rmse=12.0917, mae=8.6196, r2=0.5770
#
# ==== Forecast of DST_PLUS12 ====
#
# === SHUFFLE ===
# Linear: rmse=13.5133, mae=9.1108, r2=0.4718
# Ridge: rmse=13.5133, mae=9.1108, r2=0.4718
# Lasso: rmse=13.5129, mae=9.1104, r2=0.4719
# LGBM: rmse=13.5813, mae=9.0039, r2=0.4665
# MLP: rmse=15.7604, mae=10.7568, r2=0.2816
#
# ==== Forecast of DST_PLUS24 ====
#
# === SHUFFLE ===
# Linear: rmse=16.3013, mae=10.6432, r2=0.2312
# Ridge: rmse=16.3013, mae=10.6432, r2=0.2312
# Lasso: rmse=16.3008, mae=10.6432, r2=0.2313
# LGBM: rmse=16.4117, mae=10.5894, r2=0.2208
# MLP: rmse=19.6484, mae=13.4023, r2=-0.1169

# %%
results_df = pd.DataFrame(results_list)

# %%
results_df
# Out:
#          Target     Delays Scenario Forecast_model       RMSE        MAE  \
# 0     Dst_plus1        24h  ace-ace         Linear   3.438899   2.401378
# 1     Dst_plus1        24h  ace-ace          Ridge   3.439189   2.401620
# 2     Dst_plus1        24h  ace-ace          Lasso   3.440365   2.401460
# 3     Dst_plus1        24h  ace-ace           LGBM   4.088073   2.476720
# 4     Dst_plus1        24h  ace-ace            MLP   3.735850   2.666253
# ..          ...        ...      ...            ...        ...        ...
# 295  Dst_plus24  auto_func  shuffle         Linear  16.301299  10.643222
# 296  Dst_plus24  auto_func  shuffle          Ridge  16.301301  10.643227
# 297  Dst_plus24  auto_func  shuffle          Lasso  16.300820  10.643246
# 298  Dst_plus24  auto_func  shuffle           LGBM  16.411679  10.589363
# 299  Dst_plus24  auto_func  shuffle            MLP  19.648405  13.402318
#
#            R2
# 0    0.965960
# 1    0.965954
# 2    0.965931
# 3    0.951895
# 4    0.959827
# ..        ...
# 295  0.231234
# 296  0.231234
# 297  0.231279
# 298  0.220788
# 299 -0.116874
#
# [300 rows x 7 columns]

# %%
results_df.to_excel("../results/models_no_adaptation_split_date_2022-01-01.xlsx", index=False)
